# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as Plot

def Scatter():
    x = np.arange(0, 20, 0.2)
    y = np.cos(x)
    z = np.sin(x) 
    fig = Plot.figure()
    threedplot = Plot.axes(projection ="3d")
    #C is for color, S is for Size
    threedplot.scatter3D(x, y, z, c=np.random.rand(len(x),3), s=300)
    fig.show()

    while angle <= 360:
        threedplot.view_init(30, angle)
        Plot.draw()
        Plot.pause(.001)

if __name__=="__main__":
    Scatter()
